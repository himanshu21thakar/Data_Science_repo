# %% [markdown]
# 🎨 Introduction to Matplotlib in Python
# matplotlib is a widely-used Python library for creating static, interactive, and animated visualizations. It's incredibly versatile and helps bring your data to life through a wide variety of chart types. 📊📈
#
# ✨ Key Features of Matplotlib:
#
# 1.   📈 Line Plots
# 2.   ⚫ Scatter Plots
# 3.   📊 Bar Charts
# 4.   📉 Histograms
# 5.   📐 Customizable visual styles and themes
#
#
# 🎨 Why Use Matplotlib?
# Matplotlib provides:
#
# 🧩 Extensive customization (colors, line styles, markers)
#
# 🏷️ Support for legends and annotations
#
# 📷 Export options (PNG, PDF, SVG, etc.)
#
# 🔁 Integration with other libraries (NumPy, Pandas, Seaborn)
#
# --------------------------------------------------------------------
# --------------------------------------------------------------------
#
# 🔧 Getting Started
# Before you can use Matplotlib, you need to import it. The most common convention is:
#
# #### import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ### 1. **Basic Line Plot**
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# x = [1, 2, 3, 4, 5]
# y = [2, 3, 5, 7, 11]
#
# # Create a plot
# plt.plot(x, y, marker='o', linestyle='-', color='b', label='Prime Numbers')
#
# # Add labels and title
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.title('Basic Line Plot')
# plt.legend()
#
# # Show the plot
# plt.show()
# ```
#
# ---
#
# ### 2. **Bar Chart**
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# categories = ['A', 'B', 'C', 'D']
# values = [10, 20, 15, 25]
#
# # Create a bar chart
# plt.bar(categories, values, color='skyblue')
#
# # Add labels and title
# plt.xlabel('Categories')
# plt.ylabel('Values')
# plt.title('Bar Chart Example')
#
# # Show the plot
# plt.show()
# ```
#
# ---
#
# ### 3. **Scatter Plot**
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# x = [1, 2, 3, 4, 5]
# y = [2, 3, 5, 7, 11]
#
# # Create a scatter plot
# plt.scatter(x, y, color='red', label='Data Points')
#
# # Add labels and title
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.title('Scatter Plot Example')
# plt.legend()
#
# # Show the plot
# plt.show()
# ```
#
# ---
#
# ### 4. **Histogram**
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Generate random data
# data = np.random.normal(100, 20, 1000)
#
# # Create a histogram
# plt.hist(data, bins=30, color='green', edgecolor='black')
#
# # Add labels and title
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.title('Histogram Example')
#
# # Show the plot
# plt.show()
# ```
#
# ---
#
# ### 5. **Pie Chart**
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# labels = ['A', 'B', 'C', 'D']
# sizes = [15, 30, 45, 10]
# colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']
#
# # Create a pie chart
# plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
#
# # Add title
# plt.title('Pie Chart Example')
#
# # Show the plot
# plt.show()
# ```
#
# ---
#
# ### 6. **Multiple Plots (Subplots)**
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Data
# x = np.linspace(0, 10, 100)
# y1 = np.sin(x)
# y2 = np.cos(x)
#
# # Create subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
#
# # Plot 1
# ax1.plot(x, y1, color='blue')
# ax1.set_title('Sine Wave')
#
# # Plot 2
# ax2.plot(x, y2, color='red')
# ax2.set_title('Cosine Wave')
#
# # Add common labels
# fig.suptitle('Multiple Plots Example')
# plt.show()
# ```
#
# ---
#
# ### 7. **Customizing Plots**
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# x = [1, 2, 3, 4, 5]
# y = [2, 3, 5, 7, 11]
#
# # Create a plot with customizations
# plt.plot(x, y, marker='o', linestyle='--', color='purple', linewidth=2, markersize=8, label='Custom Line')
#
# # Add grid, labels, and title
# plt.grid(True, linestyle=':', alpha=0.7)
# plt.xlabel('X-axis', fontsize=12)
# plt.ylabel('Y-axis', fontsize=12)
# plt.title('Customized Plot', fontsize=14)
# plt.legend()
#
# # Show the plot
# plt.show()
# ```
#
# ---
#
# ### 8. **3D Plot**
# ```python
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
# import numpy as np
#
# # Data
# x = np.linspace(-5, 5, 100)
# y = np.linspace(-5, 5, 100)
# x, y = np.meshgrid(x, y)
# z = np.sin(np.sqrt(x**2 + y**2))
#
# # Create a 3D plot
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(x, y, z, cmap='viridis')
#
# # Add labels and title
# ax.set_xlabel('X-axis')
# ax.set_ylabel('Y-axis')
# ax.set_zlabel('Z-axis')
# ax.set_title('3D Surface Plot')
#
# # Show the plot
# plt.show()
# ```
#
# ---
#
# ### 9. **Saving a Plot to a File**
# ```python
# import matplotlib.pyplot as plt
#
# # Data
# x = [1, 2, 3, 4, 5]
# y = [2, 3, 5, 7, 11]
#
# # Create a plot
# plt.plot(x, y, marker='o', linestyle='-', color='b')
#
# # Add labels and title
# plt.xlabel('X-axis')
# plt.ylabel('Y-axis')
# plt.title('Saving a Plot')
#
# # Save the plot to a file
# plt.savefig('my_plot.png', dpi=300)
#
# # Show the plot
# plt.show()
# ```
#
# ---

# %%
import matplotlib.pyplot as plt

# %%
x = [3,2,4,5,6,5,6,7,8,7,5,3]
y = [7,6,5,6,4,3,4,5,6,5,5,6]

# %%
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a plot
plt.plot(x, y, marker='o', linestyle='-', color='b', label='Prime Numbers')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Basic Line Plot')
plt.legend()
plt.grid()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
names = ['Vishal', 'Mayuri', 'Chaitanya', 'Bhushan']
salaries = [14500, 20000, 15000, 25000]

# Create a bar chart
plt.bar(names, salaries, color='skyblue')

# Add labels and title
plt.xlabel('Names')
plt.ylabel('Salary')
plt.title('Bar Chart Example')
plt.grid()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a scatter plot
plt.scatter(x, y, color='red', label='Data Points',marker="*")

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')
plt.legend()

# Show the plot
plt.show()

# %%
l = [2,3,2,3,5,6,7,5,4,6,8,9,6,6]

# %%
plt.hist(l,edgecolor='black')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
data = np.random.normal(100, 20, 1000)

# Create a histogram
plt.hist(data, bins=40, color='green', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
labels = ['Vishal', 'Yugal', 'Bhushan', 'Mayuri']
sizes = [15, 30, 45, 10]
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']

# Create a pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

# Add title
plt.title('Pie Chart Example')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# Plot 1
ax1.plot(x, y1, color='blue')
ax1.set_title('Sine Wave')

# Plot 2
ax2.plot(x, y2, color='red')
ax2.set_title('Cosine Wave')

# Add common labels
fig.suptitle('Multiple Plots Example')
plt.show()

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
y = np.sin(x)
y
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
plt.plot(x,np.cos(x))

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a plot with customizations
plt.plot(x, y, marker='*', linestyle='-', color='red', linewidth=0.5, markersize=6, label='Custom Line')

# Add grid, labels, and title
plt.grid(True, linestyle=':', alpha=0.7)
plt.xlabel('X-axis', fontsize=12)
plt.ylabel('Y-axis', fontsize=12)
plt.title('Customized Plot', fontsize=14)
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Surface Plot')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a plot
plt.plot(x, y, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Saving a Plot')

# Save the plot to a file
plt.savefig('my_plot.png', dpi=300)

# Show the plot
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('car_price_dataset.csv')
df
# Out:
#            Brand     Model  Year  Engine_Size Fuel_Type    Transmission  \
# 0            Kia       Rio  2020          4.2    Diesel          Manual
# 1      Chevrolet    Malibu  2012          2.0    Hybrid       Automatic
# 2       Mercedes       GLA  2020          4.2    Diesel       Automatic
# 3           Audi        Q5  2023          2.0  Electric          Manual
# 4     Volkswagen      Golf  2003          2.6    Hybrid  Semi-Automatic
# ...          ...       ...   ...          ...       ...             ...
# 9995         Kia    Optima  2004          3.7    Diesel  Semi-Automatic
# 9996   Chevrolet    Impala  2002          1.4  Electric       Automatic
# 9997         BMW  3 Series  2010          3.0    Petrol       Automatic
# 9998        Ford  Explorer  2002          1.4    Hybrid       Automatic
# 9999  Volkswagen    Tiguan  2001          2.1    Diesel          Manual
#
#       Mileage  Doors  Owner_Count  Price
# 0      289944      3            5   8501
# ...

# %%
df['Engine_Size']
# Out:
# 0       4.2
# 1       2.0
# 2       4.2
# 3       2.0
# 4       2.6
#        ...
# 9995    3.7
# 9996    1.4
# 9997    3.0
# 9998    1.4
# 9999    2.1
# Name: Engine_Size, Length: 10000, dtype: float64
