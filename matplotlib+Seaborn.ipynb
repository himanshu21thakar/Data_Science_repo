# %% [markdown]
# # 📊 Introduction to Matplotlib and Seaborn
#
# **Matplotlib** is a popular Python library used for data visualization. It provides a flexible way to create static, animated, and interactive plots like line graphs, bar charts, scatter plots, histograms, and more.
#
# **Seaborn** is built on top of matplotlib and provides a high-level interface for drawing attractive and informative statistical graphics. It simplifies complex visualizations and integrates well with pandas DataFrames.

# %%
import matplotlib.pyplot as plt

# 📌 Importing the Matplotlib library for plotting

# %%
# 📊 Defining data points for plotting
x = [4,3,5,6,4,4,5,7]
y = [5,3,3,5,6,7,6,7]

# %%
plt.plot(x,y)
plt.grid()

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a plot
plt.plot(x, y, marker='o', linestyle='-', color='b', label='Prime Numbers')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Basic Line Plot')
plt.legend()

# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
# 🔹 Scatter plot to show relationship between x and y
plt.scatter(x,y,marker=',',s=100)

# %%
names = ['Abhishek','Rohan','Abhay','Atharva']
income = [35000,56000,54000,30000]

# %%
plt.bar(names,income)
plt.grid(alpha = 0.3)

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D']
values = [10, 20, 15, 25]

# Create a bar chart
plt.bar(categories, values, color='skyblue')

# Add labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart Example')

# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a scatter plot
plt.scatter(x, y,marker='+',s= 100, color='red', label='Data Points')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')
plt.legend()

# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
import numpy as np

# %%
x = np.random.randint(0,100,size=(100))

# %%
x
# Out:
# array([52, 86, 74, 77, 38, 39, 97, 20, 25, 92, 13, 52, 98, 99, 15, 42, 75,
#        94, 54, 34, 91, 20, 20, 26, 16, 46, 83, 39, 74, 11, 57, 64, 24, 67,
#        42, 88, 96, 12, 66, 76, 73, 52, 50, 22, 49, 32, 71, 74, 39, 19, 27,
#        75,  6, 26, 24, 56, 75, 16, 72, 38, 71, 94, 57,  1,  5,  3, 36, 25,
#        73, 94, 89, 34, 65, 55, 65, 25, 69, 74, 16, 82,  2, 71,  8, 69, 88,
#        72, 49, 31, 76, 73, 26, 32, 64, 42, 41, 90, 76, 46, 71, 20])

# %%
y = np.random.randint(0,100,size=(100))

# %%
y
# Out:
# array([86, 64, 46, 42, 24, 39, 56, 32, 46, 57, 99,  8, 56, 69, 13, 52, 84,
#        17, 76, 97, 50, 40, 54, 95, 37, 99, 58,  8, 13,  8, 45, 15, 38, 55,
#        96, 57, 17, 73, 62, 90, 55, 78, 22, 49, 93, 21, 47, 30, 54, 81, 58,
#        99, 74, 20, 44, 54, 74, 25, 23, 63,  6, 34, 72,  0, 22, 77, 77, 22,
#        26, 89, 83, 51, 49, 10, 43, 38, 61, 56,  0, 83, 57, 82, 22, 23, 44,
#        83, 52, 44, 39, 24, 90,  4, 70, 56, 90, 96, 15, 75, 68, 67])

# %%
# 🔹 Scatter plot to show relationship between x and y
plt.scatter(x,y,marker='+',color = 'red',s = 70, linewidths= 0.9,edgecolors='black')
plt.show()
# Out:
# /tmp/ipython-input-69-998656943.py:1: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x,y,marker='+',color = 'red',s = 70, linewidths= 0.9,edgecolors='black')

# %%
l = [3,2,3,4,3,4,5,6,5,7,7,7,7,7,7,7,7,7]

# %%
plt.hist(l)
# Out:
# (array([1., 0., 3., 0., 2., 0., 2., 0., 1., 9.]),
#  array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
data = np.random.normal(100, 20, 1000)

# Create a histogram
plt.hist(data, bins=30, color='green', edgecolor='black')

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram Example')

# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
data
# Out:
# array([ 91.51173948,  89.2117494 ,  94.07028606, 117.05773391,
#         89.08875069,  92.46599727, 102.18747073, 125.09176792,
#         87.52770816, 101.31429869, 106.36916837,  74.56851007,
#         91.13332104, 119.8026581 ,  98.70627815,  76.91616517,
#        111.01890892,  90.67088002, 109.69020596,  50.05917166,
#        108.38299108, 110.48641655,  91.45352459, 120.77534848,
#        105.28904855, 117.92735381,  81.96906281, 141.94030058,
#         80.18677656, 127.1615267 ,  86.47229962,  82.91741158,
#        113.38828601,  93.4724185 , 125.51694694, 104.89475406,
#        125.82183924, 127.9923536 , 108.59292818,  83.93931411,
#        115.91290236,  59.47174938,  96.94952942, 106.32185628,
#         98.39242056,  89.86542628, 115.52119595, 128.9912823 ,
#         98.8701742 , 106.01517583, 104.60367001, 103.73381221,
#         84.94999476,  95.38909783, 136.46707741,  87.31888242,
#         96.96577541,  59.97706637, 103.14637336, 105.31640228,
# ...

# %%
import matplotlib.pyplot as plt

# Data
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['gold', 'lightcoral', 'lightskyblue', 'lightgreen']

# Create a pie chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=10)

# Add title
plt.title('Pie Chart Example')

# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))

# Plot 1
ax1.plot(x, y1, color='blue')
ax1.set_title('Sine Wave')

# Plot 2
ax2.plot(x, y2, color='red')
ax2.set_title('Cosine Wave')

# Add common labels
fig.suptitle('Multiple Plots Example')
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a plot with customizations
plt.plot(x, y, marker='o', linestyle='--', color='purple', linewidth=2, markersize=8, label='Custom Line')

# Add grid, labels, and title
plt.grid(True, linestyle=':', alpha=0.7)
plt.xlabel('X-axis', fontsize=12)
plt.ylabel('Y-axis', fontsize=12)
plt.title('Customized Plot', fontsize=14)
plt.legend()

# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(np.sqrt(x**2 + y**2))

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='viridis')

# Add labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('3D Surface Plot')
plt.savefig('my_plot1.png', dpi=300)
# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
plt.savefig('plot3d.png')

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a plot
plt.plot(x, y, marker='o', linestyle='-', color='b')

# Add labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Saving a Plot')

# Save the plot to a file
plt.savefig('my_plot.png', dpi=300)

# Show the plot
plt.show()
# 📌 Importing the Matplotlib library for plotting

# %%
#-----------------------------------------------------------SEAborn--------------------------------------------------------------

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# 📌 Importing the Matplotlib library for plotting

# %%
# Load the tips dataset
tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 📊 Defining data points for plotting
sns.scatterplot(x = 'total_bill',y = 'tip',data = tips)
plt.title('Total bill VS tips')
plt.show()

# %%
# Line plot
sns.lineplot(x="total_bill", y="tip", data=tips)
plt.title("Total Bill vs Tip (Line Plot)")
plt.show()

# %%
# Bar plot
sns.barplot(x="day", y="total_bill", data=tips,color='lightblue')
plt.title("Total Bill by Day")
plt.grid(axis = 'y',alpha = 0.3)
plt.show()

# %%
tips['day'].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
# Histogram
sns.histplot(tips["total_bill"], kde=True)
plt.title("Distribution of Total Bill")
plt.show()

# %%
# Box plot
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("Total Bill by Day (Box Plot)")
plt.grid()
plt.show()

# %%
# Violin plot
sns.violinplot(x="day", y="total_bill", data=tips)
plt.title("Total Bill by Day (Violin Plot)")
plt.show()

# %%
# Pair plot
sns.pairplot(tips, hue="sex")
plt.show()

# %%
# 🔸 Seaborn scatter plot with labeled axes and title
# Facet grid
g = sns.FacetGrid(tips, col="time", row="smoker")
g.map(sns.scatterplot, "total_bill", "tip")
plt.show()
plt.xlabel("Total Bill")  # X-axis label
plt.ylabel("Tip")  # Y-axis label
plt.title("Scatterplot of Total Bill vs Tip")  # Title for the chart

# %%
# 🔸 Seaborn scatter plot with labeled axes and title
# Customizing a scatter plot
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="time", style="smoker", size="size")
plt.title("Customized Scatter Plot")
plt.xlabel("Total Bill ($)")
plt.ylabel("Tip ($)")
plt.legend(title="Time", loc="upper right")
plt.show()

# %%
# 🔸 Seaborn scatter plot with labeled axes and title
# Save a plot
sns.scatterplot(x="total_bill", y="tip", data=tips)
plt.title("Total Bill vs Tip")
plt.savefig("scatter_plot.png")
plt.xlabel("Total Bill")  # X-axis label
plt.ylabel("Tip")  # Y-axis label
plt.title("Scatterplot of Total Bill vs Tip")  # Title for the chart

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.get_dataset_names()
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
sns.pairplot(df,hue='species')
